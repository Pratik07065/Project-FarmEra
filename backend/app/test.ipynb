# %%
import joblib
import pandas as pd

# %%
model = joblib.load("onion_pipeline.pkl")

print("loaded")
# Out:
# loaded

# %%
input_data = pd.DataFrame([{
    "State": "Maharashtra",
    "District": "Nashik",
    "Market": "Lasalgaon",
    "Commodity": "Onion",
    "Variety": "Other",     # add this
    "Grade": "FAQ",         # add this
    "Day": 15,
    "Month": 3,
    "Year": 2026
}])

# %%
prediction = model.predict(input_data)
print(prediction)
# Out:
# [[ 776.875  1764.16   1482.1399]]
